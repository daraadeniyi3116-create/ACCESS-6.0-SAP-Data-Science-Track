# %% [markdown]
# <a href="https://colab.research.google.com/github/daraadeniyi3116-create/ACCESS-6.0-SAP-Data-Science-Track/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

Wh = pd.read_csv('/content/Warehouse_and_Retail_Sales.csv')

# %%
Wh.head(5)
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
#
#                       ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                  BOOTLEG RED - 750ML      WINE          0.00
# 1            MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3        SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4       SANTORINI GAVALA WHITE - 750ML      WINE          0.82
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               0.0              2.0
# 1               1.0              4.0
# 2               0.0              1.0
# 3               0.0              1.0
# ...

# %% [markdown]
# What are the first 3 things you notice in your dataset?
#
# 1. I notice that some columns have text values (like Supplier), while others have numerical values (like Sales).
#
# 2. I notice there are exactly 9 columns in the dataset, excluding the index number on the left.
#
# 3. I notice that the "Item Type" column seems to have repeated text values, which suggests groups like Wine or Beer appear many times.

# %%
Wh.tail()
# Out:
#         YEAR  MONTH                     SUPPLIER ITEM CODE  \
# 307640  2020      9                  LEGENDS LTD     99753
# 307641  2020      9           ANHEUSER BUSCH INC      9997
# 307642  2020      9  COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9      BOSTON BEER CORPORATION     99990
# 307644  2020      9                          NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 307640         DUTCHESS DE BOURGOGNE NR - 750ML      BEER          0.00
# 307641                  HOEGAARDEN 4/6NR - 12OZ      BEER         66.12
# 307642  DOMINION OAK BARREL STOUT 4/6 NR - 12OZ      BEER          2.25
# 307643         SAM ADAMS SUMMER VARIETY 12PK NR      BEER         20.50
# 307644                              WINE CREDIT       REF          0.00
#
#         RETAIL TRANSFERS  WAREHOUSE SALES
# 307640               0.0             5.00
# 307641              37.0           240.75
# 307642               0.0             0.00
# ...

# %% [markdown]
# Are there any unusual patterns in the last few rows?
#
# 1. I noticed that the very last row has a negative value (-70.00) in the "Warehouse Sales" column, which suggests it might be a refund or a credit instead of a normal sale.
#
# 2. I see that the last row has a missing value (NaN) in the "Supplier" column, while all the other rows have proper supplier names.
#
# 3. I noticed that the "Item Code" for the last row is text ("WC") instead of a number, and the "Item Type" is listed as "REF" (Reference) which is different from the usual "BEER" or "WINE" types.

# %%
Wh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307645 entries, 0 to 307644
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   YEAR              307645 non-null  int64
#  1   MONTH             307645 non-null  int64
#  2   SUPPLIER          307478 non-null  object
#  3   ITEM CODE         307645 non-null  object
#  4   ITEM DESCRIPTION  307645 non-null  object
#  5   ITEM TYPE         307644 non-null  object
#  6   RETAIL SALES      307642 non-null  float64
#  7   RETAIL TRANSFERS  307645 non-null  float64
#  8   WAREHOUSE SALES   307645 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 21.1+ MB

# %% [markdown]
# ### Observations from df.info()
#
# **1. How many rows and columns do you have?**
# * **Rows:** There are **307,645** entries.
# * **Columns:** There are **9** columns total.
#
# **2. Which columns have missing values?**
# * **SUPPLIER:** Has 307,478 non-null values (missing 167 values).
# * **ITEM TYPE:** Has 307,644 non-null values (missing 1 value).
# * **RETAIL SALES:** Has 307,642 non-null values (missing 3 values).
#
# **3. What are the data types of each column?**
# * **Integers (int64):** YEAR, MONTH.
# * **Objects (Text):** SUPPLIER, ITEM CODE, ITEM DESCRIPTION, ITEM TYPE.
# * **Floats (float64):** RETAIL SALES, RETAIL TRANSFERS, WAREHOUSE SALES.

# %%
Wh.describe()
# Out:
#                 YEAR          MONTH   RETAIL SALES  RETAIL TRANSFERS  \
# count  307645.000000  307645.000000  307642.000000     307645.000000
# mean     2018.438525       6.423862       7.024071          6.936465
# std         1.083061       3.461812      30.986238         30.237195
# min      2017.000000       1.000000      -6.490000        -38.490000
# 25%      2017.000000       3.000000       0.000000          0.000000
# 50%      2019.000000       7.000000       0.320000          0.000000
# 75%      2019.000000       9.000000       3.267500          3.000000
# max      2020.000000      12.000000    2739.000000       1990.830000
#
#        WAREHOUSE SALES
# count    307645.000000
# mean         25.294597
# std         249.916798
# min       -7800.000000
# 25%           0.000000
# 50%           1.000000
# 75%           5.000000
# max       18317.000000

# %% [markdown]
# ### Observations from df.describe()
#
# * **Highest Mean:**
#     The column **`WAREHOUSE SALES`** has the highest mean (**25.29**), which is significantly higher than Retail Sales (~7.02).
#
# * **Unusual Maximum:**
#     The **`WAREHOUSE SALES`** column also has an unusually high maximum of **18,317.00**, which is extremely far from the average, indicating a massive outlier transaction.

# %%
Wh.shape
# Out:
# (307645, 9)

# %%
Wh.columns
# Out:
# Index(['YEAR', 'MONTH', 'SUPPLIER', 'ITEM CODE', 'ITEM DESCRIPTION',
#        'ITEM TYPE', 'RETAIL SALES', 'RETAIL TRANSFERS', 'WAREHOUSE SALES'],
#       dtype='object')

# %% [markdown]
# ### Observations from df.columns and df.shape
#
# **1. List of all column names:**
# * **YEAR**
# * **MONTH**
# * **SUPPLIER**
# * **ITEM CODE**
# * **ITEM DESCRIPTION**
# * **ITEM TYPE**
# * **RETAIL SALES**
# * **RETAIL TRANSFERS**
# * **WAREHOUSE SALES**
#
# **2. What is the full size of your dataset?**
# * **Rows:** 307,645
# * **Columns:** 9
# * **Full Shape:** (307645, 9)

# %%
Wh["RETAIL SALES"]
# Out:
# 0          0.00
# 1          0.00
# 2          0.00
# 3          0.00
# 4          0.82
#           ...
# 307640     0.00
# 307641    66.12
# 307642     2.25
# 307643    20.50
# 307644     0.00
# Name: RETAIL SALES, Length: 307645, dtype: float64

# %%
Wh["WAREHOUSE SALES"]
# Out:
# 0           2.00
# 1           4.00
# 2           1.00
# 3           1.00
# 4           0.00
#            ...
# 307640      5.00
# 307641    240.75
# 307642      0.00
# 307643      0.00
# 307644    -70.00
# Name: WAREHOUSE SALES, Length: 307645, dtype: float64

# %%
Wh["SUPPLIER"]
# Out:
# 0         REPUBLIC NATIONAL DISTRIBUTING CO
# 1                                 PWSWN INC
# 2                   RELIABLE CHURCHILL LLLP
# 3                 LANTERNA DISTRIBUTORS INC
# 4                      DIONYSOS IMPORTS INC
#                         ...
# 307640                          LEGENDS LTD
# 307641                   ANHEUSER BUSCH INC
# 307642          COASTAL BREWING COMPANY LLC
# 307643              BOSTON BEER CORPORATION
# 307644                                  NaN
# Name: SUPPLIER, Length: 307645, dtype: object

# %%
Wh["ITEM TYPE"]
# Out:
# 0         WINE
# 1         WINE
# 2         BEER
# 3         WINE
# 4         WINE
#           ...
# 307640    BEER
# 307641    BEER
# 307642    BEER
# 307643    BEER
# 307644     REF
# Name: ITEM TYPE, Length: 307645, dtype: object

# %%
Wh['RETAIL SALES'] > 1000
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 307640    False
# 307641    False
# 307642    False
# 307643    False
# 307644    False
# Name: RETAIL SALES, Length: 307645, dtype: bool

# %%
Wh[Wh['RETAIL SALES'] > 0]
# Out:
#         YEAR  MONTH                     SUPPLIER ITEM CODE  \
# 4       2020      1         DIONYSOS IMPORTS INC    100293
# 5       2020      1      KYSELA PERE ET FILS LTD    100641
# 6       2020      1     SANTA MARGHERITA USA INC    100749
# 8       2020      1           JIM BEAM BRANDS CO     10103
# 9       2020      1    INTERNATIONAL CELLARS LLC    101117
# ...      ...    ...                          ...       ...
# 307636  2020      9     SIERRA NEVADA BREWING CO     99708
# 307639  2020      9       MILLER BREWING COMPANY     99740
# 307641  2020      9           ANHEUSER BUSCH INC      9997
# 307642  2020      9  COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9      BOSTON BEER CORPORATION     99990
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 4                SANTORINI GAVALA WHITE - 750ML      WINE          0.82
# 5               CORTENOVA VENETO P/GRIG - 750ML      WINE          2.76
# ...

# %%
Wh[(Wh['ITEM TYPE'] == 'WINE') & (Wh['RETAIL SALES'] > 100)]
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 7072    2020      1  SOUTHERN GLAZERS WINE AND SPIRITS     42220
# 9018    2020      1                 E & J GALLO WINERY     67563
# 10037   2020      1                 E & J GALLO WINERY     73628
# 10248   2020      1               CONSTELLATION BRANDS     75841
# 10251   2020      1               CONSTELLATION BRANDS     75906
# ...      ...    ...                                ...       ...
# 306858  2020      9               CONSTELLATION BRANDS     83837
# 306861  2020      9                   NEW PARROTT & CO     83879
# 306948  2020      9               CONSTELLATION BRANDS     84594
# 306964  2020      9                 E & J GALLO WINERY     84678
# 307017  2020      9                      J LOHR WINERY     85057
#
#                             ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 7072                OYSTER BAY S/BLC - 750ML      WINE        109.56
# ...

# %%
Wh.loc[Wh['WAREHOUSE SALES'] > 5000, ['SUPPLIER', 'ITEM DESCRIPTION']]
# Out:
#                       SUPPLIER                    ITEM DESCRIPTION
# 1363             CROWN IMPORTS        CORONA EXTRA LOOSE NR - 12OZ
# 1872              HEINEKEN USA            HEINEKEN LOOSE NR - 12OZ
# 2232             CROWN IMPORTS  MODELO ESPECIAL 24 LOOSE NR - 12OZ
# 11854            CROWN IMPORTS         CORONA EXTRA 2/12 NR - 12OZ
# 13281            CROWN IMPORTS        CORONA EXTRA LOOSE NR - 12OZ
# ...                        ...                                 ...
# 307343  MILLER BREWING COMPANY         MILLER LITE 30PK CAN - 12OZ
# 307484           CROWN IMPORTS     MODELO ESPECIAL-2/12 CAN - 12OZ
# 307522           CROWN IMPORTS         CORONA EXTRA 2/12 NR - 12OZ
# 307532            HEINEKEN USA             HEINEKEN 2/12 NR - 12OZ
# 307620           CROWN IMPORTS      MODELO ESPECIAL 2/12 NR - 12OZ
#
# [157 rows x 2 columns]

# %%
Wh.iloc[0:5, 0:3]
# Out:
#    YEAR  MONTH                           SUPPLIER
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO
# 1  2020      1                          PWSWN INC
# 2  2020      1            RELIABLE CHURCHILL LLLP
# 3  2020      1          LANTERNA DISTRIBUTORS INC
# 4  2020      1               DIONYSOS IMPORTS INC

# %%
Wh.iloc[10:21, 2:5]
# Out:
#                                 SUPPLIER ITEM CODE  \
# 10          HEAVEN HILL DISTILLERIES INC     10120
# 11                 BACCHUS IMPORTERS LTD     10123
# 12                 BACCHUS IMPORTERS LTD     10124
# 13                 BACCHUS IMPORTERS LTD     10125
# 14             MONSIEUR TOUTON SELECTION    101346
# 15  THE COUNTRY VINTNER, LLC DBA WINEBOW    101486
# 16  THE COUNTRY VINTNER, LLC DBA WINEBOW    101532
# 17                       ROYAL WINE CORP    101664
# 18     REPUBLIC NATIONAL DISTRIBUTING CO    101702
# 19                       ROYAL WINE CORP    101753
# 20                       ROYAL WINE CORP    101915
#
#                           ITEM DESCRIPTION
# 10           J W DANT BOURBON 100P - 1.75L
# 11  NOTEWORTHY SMALL BATCH BOURBON - 750ML
# 12        NOTEWORTHY SMALL BATCH RYE 750ML
# 13    NOTEWORTHY SMALL BATCH HONEY BBN 750
# 14              ALSACE WILLIAM GEW - 750ML
# 15        POLIZIANO ROSSO MONTEPUL - 750ML
# ...

# %%
Wh.groupby('ITEM TYPE')[['RETAIL SALES']].sum()
# Out:
#               RETAIL SALES
# ITEM TYPE
# BEER             574220.53
# DUNNAGE               0.00
# KEGS                  0.00
# LIQUOR           802691.43
# NON-ALCOHOL       34084.31
# REF                 663.63
# STR_SUPPLIES       2740.88
# WINE             746498.59

# %%
Wh.groupby('ITEM TYPE')['RETAIL SALES'].agg(['sum', 'mean', 'max'])
# Out:
#                     sum       mean      max
# ITEM TYPE
# BEER          574220.53  13.538786  1494.00
# DUNNAGE            0.00   0.000000     0.00
# KEGS               0.00   0.000000     0.00
# LIQUOR        802691.43  12.366221  1816.49
# NON-ALCOHOL    34084.31  17.892026  2739.00
# REF              663.63   5.225433    36.00
# STR_SUPPLIES    2740.88   6.767605   368.64
# WINE          746498.59   3.978355   813.84

# %% [markdown]
# ### Interpretation of Results
#
# 1.  I noticed that the "Liquor" category has the highest total sales (over 800,000), which means it makes the most money for the company.
#
# 2.  I was surprised to see that the "Non-Alcohol" category actually has the highest single transaction amount (2,739.00), which is higher than the most expensive wine or beer sold.
#
# 3.  I notice that the categories for "Dunnage" and "Kegs" have zeros for everything, which suggests they aren't sold directly to customers in this list, at least
