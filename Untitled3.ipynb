# %% [markdown]
# <a href="https://colab.research.google.com/github/daraadeniyi3116-create/ACCESS-6.0-SAP-Data-Science-Track/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Assignment"""

my_transactions = [100.50, 20.00, 50.25, 10.00, 200.00]

def analyze_transactions(transactions):
    count = len(transactions)

    total_sum = sum(transactions)

    average = total_sum / count

    print(f"Total sum: {total_sum}")
    print(f"Average: {average}")
    print(f"Number of transactions: {count}")


analyze_transactions(my_transactions)
# Out:
# Total sum: 380.75
# Average: 76.15
# Number of transactions: 5
